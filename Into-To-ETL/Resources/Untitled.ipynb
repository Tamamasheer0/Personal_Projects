# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
master_csv = 'master.csv'
moneyball_csv = 'moneyball.csv'
salaries_csv = 'Salaries.csv'

master_df = pd.read_csv(master_csv, encoding='ISO-8859-1')
moneyball_df = pd.read_csv(moneyball_csv)
salaries_df = pd.read_csv(salaries_csv)

# %%
master_df.head()
# Out:
#    lahmanID   playerID managerID       hofID  birthYear  birthMonth  birthDay  \
# 0         1  aaronha01       NaN  aaronha01h     1934.0         2.0       5.0
# 1         2  aaronto01       NaN         NaN     1939.0         8.0       5.0
# 2         3   aasedo01       NaN         NaN     1954.0         9.0       8.0
# 3         4   abadan01       NaN         NaN     1972.0         8.0      25.0
# 4         5  abadijo01       NaN         NaN     1854.0        11.0       4.0
#
#   birthCountry birthState        birthCity    ...      bats  throws  \
# 0          USA         AL           Mobile    ...         R       R
# 1          USA         AL           Mobile    ...         R       R
# 2          USA         CA           Orange    ...         R       R
# 3          USA         FL  West Palm Beach    ...         L       L
# 4          USA         PA     Philadelphia    ...         R       R
#
#        debut  finalGame            college lahman40ID lahman45ID   retroID  \
# ...

# %%
master_df.dtypes
# Out:
# lahmanID          int64
# playerID         object
# managerID        object
# hofID            object
# birthYear       float64
# birthMonth      float64
# birthDay        float64
# birthCountry     object
# birthState       object
# birthCity        object
# deathYear       float64
# deathMonth      float64
# deathDay        float64
# deathCountry     object
# deathState       object
# deathCity        object
# nameFirst        object
# nameLast         object
# nameNote         object
# nameGiven        object
# nameNick         object
# weight          float64
# height          float64
# bats             object
# throws           object
# debut            object
# finalGame        object
# college          object
# lahman40ID       object
# lahman45ID       object
# retroID          object
# holtzID          object
# bbrefID          object
# dtype: object

# %%
def create_birthday(df_row):

# %%
master_df[['birthYear', 'birthMonth', 'birthDay']] = master_df[['birthYear', 'birthMonth', 'birthDay']].astype('int')
