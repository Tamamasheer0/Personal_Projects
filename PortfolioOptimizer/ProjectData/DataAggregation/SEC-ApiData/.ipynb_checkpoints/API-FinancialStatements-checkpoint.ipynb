# %%
# Import Dependency Libraries
import requests as req
import pandas as pd
import numpy as np
import json

from bs4 import BeautifulSoup as soup
from datetime import datetime
from config import sec_api_key

# %% [markdown]
# <h3>SEC Edgar: Quick References</h3>
#
# <h4>API URI Example:</h4>
# [ Syntax ] {Protocol}://datafied.api.edgar-online.com/{Version}/{Endpoints}{Format}?{Parameters}appkey={API Key}
#
#     Protocol:  [ HTTP | HTTPS ]
#     Version:   [ v1 | v2 ]
#     Endpoints: [ corefinancials | insiders |]
#     Format:    [ JSON | XML ]
#     API Key:   "eb5c9d9f7df6f14e3b523b587c793304"
#
# <h4>API Concept Groups:</h4>
#     <ul>BS Consolidated - BalanceSheetConsolidated</ul>
#     <ul>IS Consolidated - IncomeStatementConsolidated</ul>
#     <ul>CF Consolidated - CashFlowStatementConsoidated</ul>
#     <ul>Valuation Ratios - ValuationRatiosMini</ul>
#     <ul>Profit Ratios - ProfitabilityRatiosMini</ul>
#     <ul>Leverage Ratios - LeverageRatiosMini</ul>
#     <ul>Liquidity Ratios - LiquidityRatiosMini</ul>
#     <ul>Metadata - Metadata</ul>
#     <ul>Metadata Free- MetadataFree</ul>
#     <ul>Financial Headers - FinancialHeaderData</ul>
#     <ul>Financial Ratios - FinancialRatioData</ul>
#
#
# <h4>Error Codes:</h4>
#     <ul>400 - Bad Request</ul>
#     <ul>403 - Forbidden (Failed Authentication)</ul>
#     <ul>503 - Service Unavailable</ul>
#     <ul>596 - Service Not Found (Resource Not Found)</ul>
#
# <h4>Limitations:</h4>
#     2 API Calls/Second
#     Maximum 5000 Calls/Day
#
# Documentation Resources:
# [ URL ] https://developer.edgar-online.com/docs

# %%
# SEC Edgar - API Query Request String (Balance Sheet)

def qry_balance_sheet(symbol):
    # Define Query Parameters
    baseuri = f"https://datafied.api.edgar-online.com/v2/corefinancials/ann"
    symbol = f"primarysymbols={symbol.upper()}"
    periods = "numperiods=5"
    fields = "fields=BalanceSheetConsolidated"
    appkey = f"appkey={sec_api_key}"
    debug = f"debug=true"
    
    params = [symbol, periods, fields, appkey, debug]
    queryuri = "&".join(params)
    apiquery = f"{baseuri}?{queryuri}"
    print(f"\n<API Query String> {apiquery}\n")
    
    return apiquery

# %%
# SEC Edgar - API Query Request String (Income Statment)

def qry_income_statement(symbol):
    # Define Query Parameters
    baseuri = f"https://datafied.api.edgar-online.com/v2/corefinancials/ann"
    symbol = f"primarysymbols={symbol.upper()}"
    periods = "numperiods=5"
    fields = "fields=IncomeStatementConsolidated"
    appkey = f"appkey={sec_api_key}"
    debug = f"debug=true"
    
    params = [symbol, periods, fields, appkey, debug]
    queryuri = "&".join(params)
    apiquery = f"{baseuri}?{queryuri}"
    print(f"\n<API Query String> {apiquery}\n")
    
    return apiquery

# %%
# SEC Edgar - API Query Request String (Cash Flow Statement)

def qry_cash_flow_statement(symbol):
    # Define Query Parameters
    baseuri = f"https://datafied.api.edgar-online.com/v2/corefinancials/ann"
    symbol = f"primarysymbols={symbol.upper()}"
    periods = "numperiods=5"
    fields = "fields=CashFlowStatementConsolidated"
    appkey = f"appkey={sec_api_key}"
    debug = f"debug=true"
    
    params = [symbol, periods, fields, appkey, debug]
    queryuri = "&".join(params)
    apiquery = f"{baseuri}?{queryuri}"
    print(f"\n<API Query String> {apiquery}\n")
    
    return apiquery

# %%
# [API Query] Balance Sheet
qry_aapl_bs = qry_balance_sheet("amzn")
qry_aapl_is = qry_income_statement("amzn")
qry_aapl_cf = qry_cash_flow_statement("amzn")
# Out:
# <API Query String> https://datafied.api.edgar-online.com/v2/corefinancials/ann?primarysymbols=AMZN&numperiods=5&fields=BalanceSheetConsolidated&appkey=eb5c9d9f7df6f14e3b523b587c793304&debug=true
#
#
# <API Query String> https://datafied.api.edgar-online.com/v2/corefinancials/ann?primarysymbols=AMZN&numperiods=5&fields=IncomeStatementConsolidated&appkey=eb5c9d9f7df6f14e3b523b587c793304&debug=true
#
#
# <API Query String> https://datafied.api.edgar-online.com/v2/corefinancials/ann?primarysymbols=AMZN&numperiods=5&fields=CashFlowStatementConsolidated&appkey=eb5c9d9f7df6f14e3b523b587c793304&debug=true

# %%
# [Query API] Balance Sheet

bs_response = req.get(qry_aapl_bs).json()
print(json.dumps(bs_response, indent=2, sort_keys=True))
# Out:
# {
#   "debug": {
#     "deleted": "false",
#     "fields": "accountspayableandaccruedexpenses,accruedinterest,additionalpaidincapital,additionalpaidincapitalpreferredstock,cashandcashequivalents,cashcashequivalentsandshortterminvestments,commitmentscontingencies,commonstock,deferredcharges,deferredincometaxescurrent,deferredincometaxeslongterm,goodwill,intangibleassets,inventoriesnet,longtermdeferredincometaxliabilities,longtermdeferredliabilitycharges,longterminvestments,minorityinterest,otheraccumulatedcomprehensiveincome,otherassets,othercurrentassets,othercurrentliabilities,otherequity,otherinvestments,otherliabilities,partnerscapital,pensionpostretirementobligation,preferredstock,prepaidexpenses,propertyplantequipmentnet,restrictedcash,retainedearnings,temporaryequity,totalassets,totalcurrentassets,totalcurrentliabilities,totalliabilities,totallongtermdebt,totalreceivablesnet,totalshorttermdebt,totalstockholdersequity,treasurystock,rownumber",
#     "filter": "NumPeriods lt-eq 5",
#     "limit": "25",
#     "numperiods": "5",
#     "offset": "0",
#     "primarysymbols": "AMZN",
#     "sortby": "PRIMARYSYMBOL ASC, PERIODENDDATE DESC"
#   },
#   "result": {
#     "rows": [
#       {
#         "rownum": 1,
#         "values": [
#           {
#             "field": "accountspayableandaccruedexpenses",
#             "value": 61855000000.0
#           },
#           {
#             "field": "additionalpaidincapital",
#             "value": 26791000000.0
#           },
#           {
#             "field": "cashandcashequivalents",
#             "value": 31750000000.0
#           },
#           {
#             "field": "cashcashequivalentsandshortterminvestments",
#             "value": 41250000000.0
#           },
#           {
#             "field": "commonstock",
#             "value": 5000000.0
#           },
#           {
#             "field": "goodwill",
#             "value": 14548000000.0
#           },
#           {
#             "field": "inventoriesnet",
#             "value": 17174000000.0
#           },
#           {
#             "field": "otheraccumulatedcomprehensiveincome",
#             "value": -1035000000.0
#           },
#           {
#             "field": "otherassets",
#             "value": 11202000000.0
#           },
#           {
#             "field": "otherliabilities",
#             "value": 27213000000.0
#           },
#           {
#             "field": "preferredstock",
#             "value": 0.0
#           },
#           {
#             "field": "propertyplantequipmentnet",
#             "value": 61797000000.0
#           },
#           {
#             "field": "retainedearnings",
#             "value": 19625000000.0
#           },
#           {
#             "field": "totalassets",
#             "value": 162648000000.0
#           },
#           {
#             "field": "totalcurrentassets",
#             "value": 75101000000.0
#           },
#           {
#             "field": "totalcurrentliabilities",
#             "value": 68391000000.0
#           },
#           {
#             "field": "totalliabilities",
#             "value": 119099000000.0
#           },
#           {
#             "field": "totallongtermdebt",
#             "value": 23495000000.0
#           },
#           {
#             "field": "totalreceivablesnet",
#             "value": 16677000000.0
#           },
#           {
#             "field": "totalstockholdersequity",
#             "value": 43549000000.0
#           },
#           {
#             "field": "treasurystock",
#             "value": -1837000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 2,
#         "values": [
#           {
#             "field": "accountspayableandaccruedexpenses",
#             "value": 52786000000.0
#           },
#           {
#             "field": "additionalpaidincapital",
#             "value": 21389000000.0
#           },
#           {
#             "field": "cashandcashequivalents",
#             "value": 20522000000.0
#           },
#           {
#             "field": "cashcashequivalentsandshortterminvestments",
#             "value": 30986000000.0
#           },
#           {
#             "field": "commonstock",
#             "value": 5000000.0
#           },
#           {
#             "field": "goodwill",
#             "value": 13350000000.0
#           },
#           {
#             "field": "inventoriesnet",
#             "value": 16047000000.0
#           },
#           {
#             "field": "otheraccumulatedcomprehensiveincome",
#             "value": -484000000.0
#           },
#           {
#             "field": "otherassets",
#             "value": 8897000000.0
#           },
#           {
#             "field": "otherliabilities",
#             "value": 20975000000.0
#           },
#           {
#             "field": "preferredstock",
#             "value": 0.0
#           },
#           {
#             "field": "propertyplantequipmentnet",
#             "value": 48866000000.0
#           },
#           {
#             "field": "retainedearnings",
#             "value": 8636000000.0
#           },
#           {
#             "field": "totalassets",
#             "value": 131310000000.0
#           },
#           {
#             "field": "totalcurrentassets",
#             "value": 60197000000.0
#           },
#           {
#             "field": "totalcurrentliabilities",
#             "value": 57883000000.0
#           },
#           {
#             "field": "totalliabilities",
#             "value": 103601000000.0
#           },
#           {
#             "field": "totallongtermdebt",
#             "value": 24743000000.0
#           },
#           {
#             "field": "totalreceivablesnet",
#             "value": 13164000000.0
#           },
#           {
#             "field": "totalstockholdersequity",
#             "value": 27709000000.0
#           },
#           {
#             "field": "treasurystock",
#             "value": -1837000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 3,
#         "values": [
#           {
#             "field": "accountspayableandaccruedexpenses",
#             "value": 39048000000.0
#           },
#           {
#             "field": "additionalpaidincapital",
#             "value": 17186000000.0
#           },
#           {
#             "field": "cashandcashequivalents",
#             "value": 19334000000.0
#           },
#           {
#             "field": "cashcashequivalentsandshortterminvestments",
#             "value": 25981000000.0
#           },
#           {
#             "field": "commonstock",
#             "value": 5000000.0
#           },
#           {
#             "field": "goodwill",
#             "value": 3784000000.0
#           },
#           {
#             "field": "inventoriesnet",
#             "value": 11461000000.0
#           },
#           {
#             "field": "otheraccumulatedcomprehensiveincome",
#             "value": -985000000.0
#           },
#           {
#             "field": "otherassets",
#             "value": 4723000000.0
#           },
#           {
#             "field": "otherliabilities",
#             "value": 12607000000.0
#           },
#           {
#             "field": "preferredstock",
#             "value": 0.0
#           },
#           {
#             "field": "propertyplantequipmentnet",
#             "value": 29114000000.0
#           },
#           {
#             "field": "retainedearnings",
#             "value": 4916000000.0
#           },
#           {
#             "field": "totalassets",
#             "value": 83402000000.0
#           },
#           {
#             "field": "totalcurrentassets",
#             "value": 45781000000.0
#           },
#           {
#             "field": "totalcurrentliabilities",
#             "value": 43816000000.0
#           },
#           {
#             "field": "totalliabilities",
#             "value": 64117000000.0
#           },
#           {
#             "field": "totallongtermdebt",
#             "value": 7694000000.0
#           },
#           {
#             "field": "totalreceivablesnet",
#             "value": 8339000000.0
#           },
#           {
#             "field": "totalstockholdersequity",
#             "value": 19285000000.0
#           },
#           {
#             "field": "treasurystock",
#             "value": -1837000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 4,
#         "values": [
#           {
#             "field": "accountspayableandaccruedexpenses",
#             "value": 30769000000.0
#           },
#           {
#             "field": "additionalpaidincapital",
#             "value": 13394000000.0
#           },
#           {
#             "field": "cashandcashequivalents",
#             "value": 15890000000.0
#           },
#           {
#             "field": "cashcashequivalentsandshortterminvestments",
#             "value": 19808000000.0
#           },
#           {
#             "field": "commonstock",
#             "value": 5000000.0
#           },
#           {
#             "field": "goodwill",
#             "value": 3759000000.0
#           },
#           {
#             "field": "inventoriesnet",
#             "value": 10243000000.0
#           },
#           {
#             "field": "otheraccumulatedcomprehensiveincome",
#             "value": -723000000.0
#           },
#           {
#             "field": "otherassets",
#             "value": 3445000000.0
#           },
#           {
#             "field": "otherliabilities",
#             "value": 9249000000.0
#           },
#           {
#             "field": "preferredstock",
#             "value": 0.0
#           },
#           {
#             "field": "propertyplantequipmentnet",
#             "value": 21838000000.0
#           },
#           {
#             "field": "retainedearnings",
#             "value": 2545000000.0
#           },
#           {
#             "field": "totalassets",
#             "value": 64747000000.0
#           },
#           {
#             "field": "totalcurrentassets",
#             "value": 35705000000.0
#           },
#           {
#             "field": "totalcurrentliabilities",
#             "value": 33887000000.0
#           },
#           {
#             "field": "totalliabilities",
#             "value": 51363000000.0
#           },
#           {
#             "field": "totallongtermdebt",
#             "value": 8227000000.0
#           },
#           {
#             "field": "totalreceivablesnet",
#             "value": 5654000000.0
#           },
#           {
#             "field": "totalstockholdersequity",
#             "value": 13384000000.0
#           },
#           {
#             "field": "treasurystock",
#             "value": -1837000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 5,
#         "values": [
#           {
#             "field": "accountspayableandaccruedexpenses",
#             "value": 26266000000.0
#           },
#           {
#             "field": "additionalpaidincapital",
#             "value": 11135000000.0
#           },
#           {
#             "field": "cashandcashequivalents",
#             "value": 14557000000.0
#           },
#           {
#             "field": "cashcashequivalentsandshortterminvestments",
#             "value": 17416000000.0
#           },
#           {
#             "field": "commonstock",
#             "value": 5000000.0
#           },
#           {
#             "field": "goodwill",
#             "value": 3319000000.0
#           },
#           {
#             "field": "inventoriesnet",
#             "value": 8299000000.0
#           },
#           {
#             "field": "otheraccumulatedcomprehensiveincome",
#             "value": -511000000.0
#           },
#           {
#             "field": "otherassets",
#             "value": 2892000000.0
#           },
#           {
#             "field": "otherliabilities",
#             "value": 7410000000.0
#           },
#           {
#             "field": "preferredstock",
#             "value": 0.0
#           },
#           {
#             "field": "propertyplantequipmentnet",
#             "value": 16967000000.0
#           },
#           {
#             "field": "retainedearnings",
#             "value": 1949000000.0
#           },
#           {
#             "field": "totalassets",
#             "value": 54505000000.0
#           },
#           {
#             "field": "totalcurrentassets",
#             "value": 31327000000.0
#           },
#           {
#             "field": "totalcurrentliabilities",
#             "value": 28089000000.0
#           },
#           {
#             "field": "totalliabilities",
#             "value": 43764000000.0
#           },
#           {
#             "field": "totallongtermdebt",
#             "value": 8265000000.0
#           },
#           {
#             "field": "totalreceivablesnet",
#             "value": 5612000000.0
#           },
#           {
#             "field": "totalstockholdersequity",
#             "value": 10741000000.0
#           },
#           {
#             "field": "treasurystock",
#             "value": -1837000000.0
#           }
#         ]
#       }
#     ],
#     "totalrows": 5
#   }
# }

# %%
# [Query API] Income Statement

is_response = req.get(qry_aapl_is).json()
print(json.dumps(is_response, indent=2, sort_keys=True))
# Out:
# {
#   "debug": {
#     "deleted": "false",
#     "fields": "accountingchange,basicepsnetincome,costofrevenue,depreciationamortizationexpense,dilutedepsnetincome,discontinuedoperations,ebit,equityearnings,extraordinaryitems,grossprofit,incomebeforeextraordinaryitems,incomebeforetaxes,incometaxes,interestexpense,interestincome,minorityinterestequityearnings,netincome,netincomeapplicabletocommon,operatingprofit,othernonoperatingincomeexpense,otheroperatingexpenses,researchdevelopmentexpense,restructuringremediationimpairmentprovisions,sellinggeneraladministrativeexpenses,totalrevenue,rownumber",
#     "filter": "NumPeriods lt-eq 5",
#     "limit": "25",
#     "numperiods": "5",
#     "offset": "0",
#     "primarysymbols": "AMZN",
#     "sortby": "PRIMARYSYMBOL ASC, PERIODENDDATE DESC"
#   },
#   "result": {
#     "rows": [
#       {
#         "rownum": 1,
#         "values": [
#           {
#             "field": "basicepsnetincome",
#             "value": 20.68
#           },
#           {
#             "field": "costofrevenue",
#             "value": 139156000000.0
#           },
#           {
#             "field": "dilutedepsnetincome",
#             "value": 20.14
#           },
#           {
#             "field": "ebit",
#             "value": 12421000000.0
#           },
#           {
#             "field": "equityearnings",
#             "value": 9000000.0
#           },
#           {
#             "field": "grossprofit",
#             "value": 93731000000.0
#           },
#           {
#             "field": "incomebeforeextraordinaryitems",
#             "value": 10073000000.0
#           },
#           {
#             "field": "incomebeforetaxes",
#             "value": 11261000000.0
#           },
#           {
#             "field": "incometaxes",
#             "value": 1197000000.0
#           },
#           {
#             "field": "interestexpense",
#             "value": -1417000000.0
#           },
#           {
#             "field": "interestincome",
#             "value": 440000000.0
#           },
#           {
#             "field": "minorityinterestequityearnings",
#             "value": 9000000.0
#           },
#           {
#             "field": "netincome",
#             "value": 10073000000.0
#           },
#           {
#             "field": "netincomeapplicabletocommon",
#             "value": 10073000000.0
#           },
#           {
#             "field": "operatingprofit",
#             "value": 12421000000.0
#           },
#           {
#             "field": "othernonoperatingincomeexpense",
#             "value": -183000000.0
#           },
#           {
#             "field": "otheroperatingexpenses",
#             "value": 63160000000.0
#           },
#           {
#             "field": "sellinggeneraladministrativeexpenses",
#             "value": 18150000000.0
#           },
#           {
#             "field": "totalrevenue",
#             "value": 232887000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 2,
#         "values": [
#           {
#             "field": "basicepsnetincome",
#             "value": 6.32
#           },
#           {
#             "field": "costofrevenue",
#             "value": 111934000000.0
#           },
#           {
#             "field": "dilutedepsnetincome",
#             "value": 6.15
#           },
#           {
#             "field": "ebit",
#             "value": 4106000000.0
#           },
#           {
#             "field": "equityearnings",
#             "value": -4000000.0
#           },
#           {
#             "field": "grossprofit",
#             "value": 65932000000.0
#           },
#           {
#             "field": "incomebeforeextraordinaryitems",
#             "value": 3033000000.0
#           },
#           {
#             "field": "incomebeforetaxes",
#             "value": 3806000000.0
#           },
#           {
#             "field": "incometaxes",
#             "value": 769000000.0
#           },
#           {
#             "field": "interestexpense",
#             "value": -848000000.0
#           },
#           {
#             "field": "interestincome",
#             "value": 202000000.0
#           },
#           {
#             "field": "minorityinterestequityearnings",
#             "value": -4000000.0
#           },
#           {
#             "field": "netincome",
#             "value": 3033000000.0
#           },
#           {
#             "field": "netincomeapplicabletocommon",
#             "value": 3033000000.0
#           },
#           {
#             "field": "operatingprofit",
#             "value": 4106000000.0
#           },
#           {
#             "field": "othernonoperatingincomeexpense",
#             "value": 346000000.0
#           },
#           {
#             "field": "otheroperatingexpenses",
#             "value": 48083000000.0
#           },
#           {
#             "field": "sellinggeneraladministrativeexpenses",
#             "value": 13743000000.0
#           },
#           {
#             "field": "totalrevenue",
#             "value": 177866000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 3,
#         "values": [
#           {
#             "field": "basicepsnetincome",
#             "value": 5.01
#           },
#           {
#             "field": "costofrevenue",
#             "value": 88265000000.0
#           },
#           {
#             "field": "dilutedepsnetincome",
#             "value": 4.9
#           },
#           {
#             "field": "ebit",
#             "value": 4186000000.0
#           },
#           {
#             "field": "equityearnings",
#             "value": -96000000.0
#           },
#           {
#             "field": "grossprofit",
#             "value": 47722000000.0
#           },
#           {
#             "field": "incomebeforeextraordinaryitems",
#             "value": 2371000000.0
#           },
#           {
#             "field": "incomebeforetaxes",
#             "value": 3892000000.0
#           },
#           {
#             "field": "incometaxes",
#             "value": 1425000000.0
#           },
#           {
#             "field": "interestexpense",
#             "value": -484000000.0
#           },
#           {
#             "field": "interestincome",
#             "value": 100000000.0
#           },
#           {
#             "field": "minorityinterestequityearnings",
#             "value": -96000000.0
#           },
#           {
#             "field": "netincome",
#             "value": 2371000000.0
#           },
#           {
#             "field": "netincomeapplicabletocommon",
#             "value": 2371000000.0
#           },
#           {
#             "field": "operatingprofit",
#             "value": 4186000000.0
#           },
#           {
#             "field": "othernonoperatingincomeexpense",
#             "value": 90000000.0
#           },
#           {
#             "field": "otheroperatingexpenses",
#             "value": 33871000000.0
#           },
#           {
#             "field": "sellinggeneraladministrativeexpenses",
#             "value": 9665000000.0
#           },
#           {
#             "field": "totalrevenue",
#             "value": 135987000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 4,
#         "values": [
#           {
#             "field": "basicepsnetincome",
#             "value": 1.28
#           },
#           {
#             "field": "costofrevenue",
#             "value": 71651000000.0
#           },
#           {
#             "field": "dilutedepsnetincome",
#             "value": 1.25
#           },
#           {
#             "field": "ebit",
#             "value": 2233000000.0
#           },
#           {
#             "field": "equityearnings",
#             "value": -22000000.0
#           },
#           {
#             "field": "grossprofit",
#             "value": 35355000000.0
#           },
#           {
#             "field": "incomebeforeextraordinaryitems",
#             "value": 596000000.0
#           },
#           {
#             "field": "incomebeforetaxes",
#             "value": 1568000000.0
#           },
#           {
#             "field": "incometaxes",
#             "value": 950000000.0
#           },
#           {
#             "field": "interestexpense",
#             "value": -459000000.0
#           },
#           {
#             "field": "interestincome",
#             "value": 50000000.0
#           },
#           {
#             "field": "minorityinterestequityearnings",
#             "value": -22000000.0
#           },
#           {
#             "field": "netincome",
#             "value": 596000000.0
#           },
#           {
#             "field": "netincomeapplicabletocommon",
#             "value": 596000000.0
#           },
#           {
#             "field": "operatingprofit",
#             "value": 2233000000.0
#           },
#           {
#             "field": "othernonoperatingincomeexpense",
#             "value": -256000000.0
#           },
#           {
#             "field": "otheroperatingexpenses",
#             "value": 26121000000.0
#           },
#           {
#             "field": "sellinggeneraladministrativeexpenses",
#             "value": 7001000000.0
#           },
#           {
#             "field": "totalrevenue",
#             "value": 107006000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 5,
#         "values": [
#           {
#             "field": "basicepsnetincome",
#             "value": -0.52
#           },
#           {
#             "field": "costofrevenue",
#             "value": 62752000000.0
#           },
#           {
#             "field": "dilutedepsnetincome",
#             "value": -0.52
#           },
#           {
#             "field": "ebit",
#             "value": 178000000.0
#           },
#           {
#             "field": "equityearnings",
#             "value": 37000000.0
#           },
#           {
#             "field": "grossprofit",
#             "value": 26236000000.0
#           },
#           {
#             "field": "incomebeforeextraordinaryitems",
#             "value": -241000000.0
#           },
#           {
#             "field": "incomebeforetaxes",
#             "value": -111000000.0
#           },
#           {
#             "field": "incometaxes",
#             "value": 167000000.0
#           },
#           {
#             "field": "interestexpense",
#             "value": -210000000.0
#           },
#           {
#             "field": "interestincome",
#             "value": 39000000.0
#           },
#           {
#             "field": "minorityinterestequityearnings",
#             "value": 37000000.0
#           },
#           {
#             "field": "netincome",
#             "value": -241000000.0
#           },
#           {
#             "field": "netincomeapplicabletocommon",
#             "value": -241000000.0
#           },
#           {
#             "field": "operatingprofit",
#             "value": 178000000.0
#           },
#           {
#             "field": "othernonoperatingincomeexpense",
#             "value": -118000000.0
#           },
#           {
#             "field": "otheroperatingexpenses",
#             "value": 20174000000.0
#           },
#           {
#             "field": "sellinggeneraladministrativeexpenses",
#             "value": 5884000000.0
#           },
#           {
#             "field": "totalrevenue",
#             "value": 88988000000.0
#           }
#         ]
#       }
#     ],
#     "totalrows": 5
#   }
# }

# %%
# [Query API] Cash Flow Statement

cf_response = req.get(qry_aapl_cf).json()
print(json.dumps(cf_response, indent=2, sort_keys=True))
# Out:
# {
#   "debug": {
#     "deleted": "false",
#     "fields": "acquisitionsaleofbusinessnet,adjustmentforequityearnings,adjustmentforminorityinterest,adjustmentforspecialcharges,capitalexpenditures,cashfromdiscontinuedoperations,cashfromfinancingactivities,cashfrominvestingactivities,cashfromoperatingactivities,cfdepreciationamortization,changeinaccountspayableaccruedexpenses,changeinaccountsreceivable,changeincurrentassets,changeincurrentliabilities,changeindebtnet,changeindeferredrevenue,changeinequitynet,changeinincometaxespayable,changeininventories,changeinoperatingassetsliabilities,changeinotherassets,changeinothercurrentassets,changeinothercurrentliabilities,changeinotherliabilities,changeinprepaidexpenses,deferredincometaxes,dividendspaid,effectofexchangerateoncash,employeecompensation,investmentchangesnet,netchangeincash,otheradjustments,otherassetliabilitychangesnet,otherfinancingactivitiesnet,otherinvestingactivities,realizedgainslosses,saleofpropertyplantequipment,stockoptiontaxbenefits,totaladjustments,rownumber",
#     "filter": "NumPeriods lt-eq 5",
#     "limit": "25",
#     "numperiods": "5",
#     "offset": "0",
#     "primarysymbols": "AMZN",
#     "sortby": "PRIMARYSYMBOL ASC, PERIODENDDATE DESC"
#   },
#   "result": {
#     "rows": [
#       {
#         "rownum": 1,
#         "values": [
#           {
#             "field": "acquisitionsaleofbusinessnet",
#             "value": -2186000000.0
#           },
#           {
#             "field": "capitalexpenditures",
#             "value": -13427000000.0
#           },
#           {
#             "field": "cashfromfinancingactivities",
#             "value": -7686000000.0
#           },
#           {
#             "field": "cashfrominvestingactivities",
#             "value": -12369000000.0
#           },
#           {
#             "field": "cashfromoperatingactivities",
#             "value": 30723000000.0
#           },
#           {
#             "field": "cfdepreciationamortization",
#             "value": 15341000000.0
#           },
#           {
#             "field": "changeinaccountspayableaccruedexpenses",
#             "value": 3735000000.0
#           },
#           {
#             "field": "changeinaccountsreceivable",
#             "value": -4615000000.0
#           },
#           {
#             "field": "changeincurrentassets",
#             "value": -5929000000.0
#           },
#           {
#             "field": "changeincurrentliabilities",
#             "value": 4886000000.0
#           },
#           {
#             "field": "changeindebtnet",
#             "value": -7686000000.0
#           },
#           {
#             "field": "changeindeferredrevenue",
#             "value": 1151000000.0
#           },
#           {
#             "field": "changeininventories",
#             "value": -1314000000.0
#           },
#           {
#             "field": "changeinoperatingassetsliabilities",
#             "value": -1043000000.0
#           },
#           {
#             "field": "changeinothercurrentassets",
#             "value": 0.0
#           },
#           {
#             "field": "changeinothercurrentliabilities",
#             "value": 0.0
#           },
#           {
#             "field": "deferredincometaxes",
#             "value": 441000000.0
#           },
#           {
#             "field": "effectofexchangerateoncash",
#             "value": -351000000.0
#           },
#           {
#             "field": "employeecompensation",
#             "value": 5418000000.0
#           },
#           {
#             "field": "investmentchangesnet",
#             "value": 1140000000.0
#           },
#           {
#             "field": "netchangeincash",
#             "value": 10317000000.0
#           },
#           {
#             "field": "otheradjustments",
#             "value": 493000000.0
#           },
#           {
#             "field": "saleofpropertyplantequipment",
#             "value": 2104000000.0
#           },
#           {
#             "field": "totaladjustments",
#             "value": 20650000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 2,
#         "values": [
#           {
#             "field": "acquisitionsaleofbusinessnet",
#             "value": -13972000000.0
#           },
#           {
#             "field": "capitalexpenditures",
#             "value": -11955000000.0
#           },
#           {
#             "field": "cashfromfinancingactivities",
#             "value": 9928000000.0
#           },
#           {
#             "field": "cashfrominvestingactivities",
#             "value": -27084000000.0
#           },
#           {
#             "field": "cashfromoperatingactivities",
#             "value": 18365000000.0
#           },
#           {
#             "field": "cfdepreciationamortization",
#             "value": 11478000000.0
#           },
#           {
#             "field": "changeinaccountspayableaccruedexpenses",
#             "value": 7383000000.0
#           },
#           {
#             "field": "changeinaccountsreceivable",
#             "value": -4780000000.0
#           },
#           {
#             "field": "changeincurrentassets",
#             "value": -8363000000.0
#           },
#           {
#             "field": "changeincurrentliabilities",
#             "value": 8121000000.0
#           },
#           {
#             "field": "changeindebtnet",
#             "value": 9928000000.0
#           },
#           {
#             "field": "changeindeferredrevenue",
#             "value": 738000000.0
#           },
#           {
#             "field": "changeininventories",
#             "value": -3583000000.0
#           },
#           {
#             "field": "changeinoperatingassetsliabilities",
#             "value": -242000000.0
#           },
#           {
#             "field": "changeinothercurrentassets",
#             "value": 0.0
#           },
#           {
#             "field": "changeinothercurrentliabilities",
#             "value": 0.0
#           },
#           {
#             "field": "deferredincometaxes",
#             "value": -29000000.0
#           },
#           {
#             "field": "effectofexchangerateoncash",
#             "value": 713000000.0
#           },
#           {
#             "field": "employeecompensation",
#             "value": 4215000000.0
#           },
#           {
#             "field": "investmentchangesnet",
#             "value": -3054000000.0
#           },
#           {
#             "field": "netchangeincash",
#             "value": 1922000000.0
#           },
#           {
#             "field": "otheradjustments",
#             "value": -90000000.0
#           },
#           {
#             "field": "saleofpropertyplantequipment",
#             "value": 1897000000.0
#           },
#           {
#             "field": "totaladjustments",
#             "value": 15332000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 3,
#         "values": [
#           {
#             "field": "acquisitionsaleofbusinessnet",
#             "value": -116000000.0
#           },
#           {
#             "field": "capitalexpenditures",
#             "value": -7804000000.0
#           },
#           {
#             "field": "cashfromfinancingactivities",
#             "value": -3716000000.0
#           },
#           {
#             "field": "cashfrominvestingactivities",
#             "value": -9516000000.0
#           },
#           {
#             "field": "cashfromoperatingactivities",
#             "value": 17203000000.0
#           },
#           {
#             "field": "cfdepreciationamortization",
#             "value": 8116000000.0
#           },
#           {
#             "field": "changeinaccountspayableaccruedexpenses",
#             "value": 6754000000.0
#           },
#           {
#             "field": "changeinaccountsreceivable",
#             "value": -3436000000.0
#           },
#           {
#             "field": "changeincurrentassets",
#             "value": -4862000000.0
#           },
#           {
#             "field": "changeincurrentliabilities",
#             "value": 8709000000.0
#           },
#           {
#             "field": "changeindebtnet",
#             "value": -3716000000.0
#           },
#           {
#             "field": "changeindeferredrevenue",
#             "value": 1955000000.0
#           },
#           {
#             "field": "changeininventories",
#             "value": -1426000000.0
#           },
#           {
#             "field": "changeinoperatingassetsliabilities",
#             "value": 3847000000.0
#           },
#           {
#             "field": "changeinothercurrentassets",
#             "value": 0.0
#           },
#           {
#             "field": "changeinothercurrentliabilities",
#             "value": 0.0
#           },
#           {
#             "field": "deferredincometaxes",
#             "value": -246000000.0
#           },
#           {
#             "field": "effectofexchangerateoncash",
#             "value": -212000000.0
#           },
#           {
#             "field": "employeecompensation",
#             "value": 2975000000.0
#           },
#           {
#             "field": "investmentchangesnet",
#             "value": -2663000000.0
#           },
#           {
#             "field": "netchangeincash",
#             "value": 3759000000.0
#           },
#           {
#             "field": "otheradjustments",
#             "value": 140000000.0
#           },
#           {
#             "field": "saleofpropertyplantequipment",
#             "value": 1067000000.0
#           },
#           {
#             "field": "totaladjustments",
#             "value": 14832000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 4,
#         "values": [
#           {
#             "field": "acquisitionsaleofbusinessnet",
#             "value": -795000000.0
#           },
#           {
#             "field": "capitalexpenditures",
#             "value": -5387000000.0
#           },
#           {
#             "field": "cashfromfinancingactivities",
#             "value": -3882000000.0
#           },
#           {
#             "field": "cashfrominvestingactivities",
#             "value": -6450000000.0
#           },
#           {
#             "field": "cashfromoperatingactivities",
#             "value": 12039000000.0
#           },
#           {
#             "field": "cfdepreciationamortization",
#             "value": 6281000000.0
#           },
#           {
#             "field": "changeinaccountspayableaccruedexpenses",
#             "value": 5207000000.0
#           },
#           {
#             "field": "changeinaccountsreceivable",
#             "value": -1755000000.0
#           },
#           {
#             "field": "changeincurrentassets",
#             "value": -3942000000.0
#           },
#           {
#             "field": "changeincurrentliabilities",
#             "value": 6499000000.0
#           },
#           {
#             "field": "changeindebtnet",
#             "value": -3882000000.0
#           },
#           {
#             "field": "changeindeferredrevenue",
#             "value": 1292000000.0
#           },
#           {
#             "field": "changeininventories",
#             "value": -2187000000.0
#           },
#           {
#             "field": "changeinoperatingassetsliabilities",
#             "value": 2557000000.0
#           },
#           {
#             "field": "changeinothercurrentassets",
#             "value": 0.0
#           },
#           {
#             "field": "changeinothercurrentliabilities",
#             "value": 0.0
#           },
#           {
#             "field": "deferredincometaxes",
#             "value": 81000000.0
#           },
#           {
#             "field": "effectofexchangerateoncash",
#             "value": -374000000.0
#           },
#           {
#             "field": "employeecompensation",
#             "value": 2119000000.0
#           },
#           {
#             "field": "investmentchangesnet",
#             "value": -1066000000.0
#           },
#           {
#             "field": "netchangeincash",
#             "value": 1333000000.0
#           },
#           {
#             "field": "otheradjustments",
#             "value": 405000000.0
#           },
#           {
#             "field": "saleofpropertyplantequipment",
#             "value": 798000000.0
#           },
#           {
#             "field": "totaladjustments",
#             "value": 11443000000.0
#           }
#         ]
#       },
#       {
#         "rownum": 5,
#         "values": [
#           {
#             "field": "acquisitionsaleofbusinessnet",
#             "value": -979000000.0
#           },
#           {
#             "field": "capitalexpenditures",
#             "value": -4893000000.0
#           },
#           {
#             "field": "cashfromfinancingactivities",
#             "value": 4432000000.0
#           },
#           {
#             "field": "cashfrominvestingactivities",
#             "value": -5065000000.0
#           },
#           {
#             "field": "cashfromoperatingactivities",
#             "value": 6842000000.0
#           },
#           {
#             "field": "cfdepreciationamortization",
#             "value": 4746000000.0
#           },
#           {
#             "field": "changeinaccountspayableaccruedexpenses",
#             "value": 2465000000.0
#           },
#           {
#             "field": "changeinaccountsreceivable",
#             "value": -1039000000.0
#           },
#           {
#             "field": "changeincurrentassets",
#             "value": -2232000000.0
#           },
#           {
#             "field": "changeincurrentliabilities",
#             "value": 6898000000.0
#           },
#           {
#             "field": "changeindebtnet",
#             "value": 4426000000.0
#           },
#           {
#             "field": "changeindeferredrevenue",
#             "value": 4433000000.0
#           },
#           {
#             "field": "changeininventories",
#             "value": -1193000000.0
#           },
#           {
#             "field": "changeinoperatingassetsliabilities",
#             "value": 974000000.0
#           },
#           {
#             "field": "changeinothercurrentassets",
#             "value": 0.0
#           },
#           {
#             "field": "changeinothercurrentliabilities",
#             "value": 0.0
#           },
#           {
#             "field": "deferredincometaxes",
#             "value": -316000000.0
#           },
#           {
#             "field": "effectofexchangerateoncash",
#             "value": -310000000.0
#           },
#           {
#             "field": "employeecompensation",
#             "value": 1497000000.0
#           },
#           {
#             "field": "investmentchangesnet",
#             "value": 807000000.0
#           },
#           {
#             "field": "netchangeincash",
#             "value": 5899000000.0
#           },
#           {
#             "field": "otheradjustments",
#             "value": 188000000.0
#           },
#           {
#             "field": "otherassetliabilitychangesnet",
#             "value": -3692000000.0
#           },
#           {
#             "field": "otherfinancingactivitiesnet",
#             "value": 6000000.0
#           },
#           {
#             "field": "stockoptiontaxbenefits",
#             "value": -6000000.0
#           },
#           {
#             "field": "totaladjustments",
#             "value": 7083000000.0
#           }
#         ]
#       }
#     ],
#     "totalrows": 5
#   }
# }

# %% [markdown]
# <h3>Explore API Response Data</h3>

# %%
# [API Response] Total Row Count (Selected # Periods)
bs_response["result"]['totalrows']
# Out:
# 5

# %%
# Each Row (Year): List of Dictionaries (BS Items)
year_0 = bs_response["result"]["rows"][0]["values"]

# %%
# Number of Balance Sheet Items
print(f"[Year_0] # of Balance Sheet Items: {len(year_0)}")
# Out:
# [Year_0] # of Balance Sheet Items: 21

# %%
# Balance Sheet Line Item Categories
y0_bs_line_items = [bs["field"] for bs in year_0]
y0_bs_line_items
# Out:
# ['accountspayableandaccruedexpenses',
#  'additionalpaidincapital',
#  'cashandcashequivalents',
#  'cashcashequivalentsandshortterminvestments',
#  'commonstock',
#  'goodwill',
#  'inventoriesnet',
#  'otheraccumulatedcomprehensiveincome',
#  'otherassets',
#  'otherliabilities',
#  'preferredstock',
#  'propertyplantequipmentnet',
#  'retainedearnings',
#  'totalassets',
#  'totalcurrentassets',
#  'totalcurrentliabilities',
#  'totalliabilities',
#  'totallongtermdebt',
#  'totalreceivablesnet',
#  'totalstockholdersequity',
#  'treasurystock']

# %%
y0_bs_line_values = [bs["value"] for bs in year_0]
y0_bs_line_values
# Out:
# [61855000000.0,
#  26791000000.0,
#  31750000000.0,
#  41250000000.0,
#  5000000.0,
#  14548000000.0,
#  17174000000.0,
#  -1035000000.0,
#  11202000000.0,
#  27213000000.0,
#  0.0,
#  61797000000.0,
#  19625000000.0,
#  162648000000.0,
#  75101000000.0,
#  68391000000.0,
#  119099000000.0,
#  23495000000.0,
#  16677000000.0,
#  43549000000.0,
#  -1837000000.0]

# %%
y0_bs_paired = {li:lv for li, lv in zip(y0_bs_line_items, y0_bs_line_values)}

# %%
# Convert Response BS Response to DataFrame
bs = pd.DataFrame({
    'bs_line_items': y0_bs_line_items,
    '($)millions': y0_bs_line_values
})

bs.head(10)
# Out:
#                                 bs_line_items   ($)millions
# 0           accountspayableandaccruedexpenses  6.185500e+10
# 1                     additionalpaidincapital  2.679100e+10
# 2                      cashandcashequivalents  3.175000e+10
# 3  cashcashequivalentsandshortterminvestments  4.125000e+10
# 4                                 commonstock  5.000000e+06
# 5                                    goodwill  1.454800e+10
# 6                              inventoriesnet  1.717400e+10
# 7         otheraccumulatedcomprehensiveincome -1.035000e+09
# 8                                 otherassets  1.120200e+10
# 9                            otherliabilities  2.721300e+10

# %%
# Preview Dataframe Column Data Types
bs.dtypes
# Out:
# bs_line_items     object
# ($)millions      float64
# dtype: object

# %%
bs["($)millions"] = bs["($)millions"].apply(lambda x: "${:,.2f} mm".format(x/1000000))
bs.head(10)
# Out:
#                                 bs_line_items     ($)millions
# 0           accountspayableandaccruedexpenses   $55,888.00 mm
# 1                      cashandcashequivalents   $25,913.00 mm
# 2  cashcashequivalentsandshortterminvestments   $66,301.00 mm
# 3                                 commonstock   $40,201.00 mm
# 4                              inventoriesnet    $3,956.00 mm
# 5            longtermdeferredliabilitycharges    $2,797.00 mm
# 6                         longterminvestments  $170,799.00 mm
# 7         otheraccumulatedcomprehensiveincome   $-3,454.00 mm
# 8                                 otherassets   $22,283.00 mm
# 9                          othercurrentassets   $12,087.00 mm
